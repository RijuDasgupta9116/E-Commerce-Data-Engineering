-- %%
CREATE TABLE IF NOT EXISTS ecommerce_dev.audit.ingestion_log (
    run_id STRING,
    layer STRING,
    table_name STRING,
    source_path STRING,
    status STRING,
    rows_ingested BIGINT,
    start_time TIMESTAMP,
    end_time TIMESTAMP,
    duration_seconds DOUBLE,
    error_message STRING,
    triggered_by STRING,
    metadata STRING
) USING DELTA
